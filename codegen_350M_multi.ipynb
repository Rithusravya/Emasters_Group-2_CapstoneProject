# %% [markdown]
# <a href="https://colab.research.google.com/github/Rithusravya/Emasters_Group-2_CapstoneProject/blob/main/codegen_350M_multi.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# Use a pipeline as a high-level helper
from transformers import pipeline

pipe = pipeline("text-generation", model="Salesforce/codegen-350M-multi")
# Out:
# ...
# WARNING:huggingface_hub.utils._http:Warning: You are sending unauthenticated requests to the HF Hub. Please set a HF_TOKEN to enable higher rate limits and faster downloads.
# config.json:   0%|          | 0.00/1.00k [00:00<?, ?B/s]
# pytorch_model.bin: reconstructing file:   0%|          |  0.00B /  797MB
# pytorch_model.bin: downloading bytes:           |  0.00B
# Loading weights:   0%|          | 0/165 [00:00<?, ?it/s]
# [transformers] CodeGenForCausalLM LOAD REPORT from: Salesforce/codegen-350M-multi
# Key                                     | Status     |  |
# ----------------------------------------+------------+--+-
# transformer.h.{0...19}.attn.causal_mask | UNEXPECTED |  |
#
# Notes:
# - UNEXPECTED:	can be ignored when loading from different task/architecture; not ok if you expect identical arch.
# model.safetensors: reconstructing file:   0%|          |  0.00B /  797MB
# model.safetensors: downloading bytes:           |  0.00B
# ...

# %%
# Load model directly
from transformers import AutoTokenizer, AutoModelForCausalLM

tokenizer = AutoTokenizer.from_pretrained("Salesforce/codegen-350M-multi")
model = AutoModelForCausalLM.from_pretrained("Salesforce/codegen-350M-multi", device_map="auto")
