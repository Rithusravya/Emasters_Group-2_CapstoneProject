# %% [markdown]
# ## Interactive config inspection notebook.
#
# The canonical loader lives in `src/config_loader.py` (a plain module, so every
# other file — notebook or script — can `from src.config_loader import CFG`
# without re-parsing YAML). This notebook just exposes it for interactive use.

# %%
from src.config_loader import CFG, load_config, reload_config

# %%
CFG
