# %% [markdown]
# # Embeddings Notebook
#
# Demonstrates how to create semantic embeddings for code and natural language text.

# %%
from src.indexing.embeddings import CodeEmbeddingGenerator

generator = CodeEmbeddingGenerator(model_name='sentence-transformers/all-MiniLM-L6-v2')
sample_texts = ['def add(a, b): return a + b', 'Write a function to sum two numbers']

# The model will be loaded when encoding is requested
print('Ready to encode', len(sample_texts), 'texts')
